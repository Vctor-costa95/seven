# %%
from pdf2image import convert_from_path
import pytesseract
import cv2
import os
import temp
import shutil
from os import listdir, path, remove, unlink, walk

# %%
dir = r"C:/Users/jvict/Documents/seven/teste equatori"
fileExt = r".pdf"
for foto in os.listdir(dir):
    if (foto.endswith(fileExt)):
        diret = f"{dir}\{foto}"
        print(foto)
        nome = foto.replace('.pdf','')+'.jpg'
        images = convert_from_path(pdf_path= diret, poppler_path=r"C:\Program Files\poppler-23.11.0\Library\bin", fmt= 'jpg',output_file= nome)
        
        path = r'C:/Program Files/Tesseract-OCR'
        images[0].save(nome)
# Out:
# [05230009002822]LOJA28ENERGISA.pdf
# [06198619000139]LOJA17ENERGISA.pdf
# [06198619000724]LOJA33ENERGISA.pdf
# [06198619001704]LOJA31ENERGISA.pdf
# [06198619002000]LOJA42ENERGISA.pdf
# [06198619003740]LOJA60ENERGISA.pdf
# [06198619004711]LOJA 36CELPE.pdf
# [06198619005106]LOJA 38EQUATORIAL.pdf
# [06198619006170]LOJA74ENERGISA.pdf
# [06198619006250]LOJA65ENERGISA.pdf
# [06198619008547]LOJA151CELPE.pdf
# [06198619009608]LOJA163CELPE.pdf

# %%
fileExt = r".jpg" 
for image in os.listdir(r"C:\Users\jvict\Documents\seven\seven"):
    if image.endswith(fileExt) or image.endswith('JPG') :
      try:
          pytesseract.pytesseract.tesseract_cmd = path + r'/tesseract.exe'
          texto = pytesseract.image_to_string(image)
          #print(images)
          #print(texto)
          lines = texto.split('\n')
          d_h = False
          p_s = False
          na_prox = False
          pls= False
          cod_ver = None
          for line in lines:
            
            if d_h == True:
              data = line.split(' ')[6]
              try: 
                  int(data.replace(':','').replace('/',''))
              except:
                data = line.split(' ')[7]
                try: 
                  int(data.replace(':','').replace('/',''))
                except:
                  data = line.split(' ')[0]
              d_h = False
              
            if p_s == True:
              cnpj_prestador = line.replace(' ','').split(':')[1][0:18]
              p_s = False
            if 'Data e Hora' in line:
              d_h = True
              
            if 'PRESTADOR DE SERVICOS' in line:
              p_s = True
              
            if 'CPF/CNPJ:' in line:
              cnpj_tomador = line.split(' ')[1]
              
            if 'VALOR TOTAL DO SERVICO' in line:
              valor = line.split(' ')[6]
              
            if 'PREFEITURA DO' in line:
              n_nota= line.split(' ')[2]
              
            if 'Nota Fiscal de' in line:
                cod_ver = line.split(' ')[-1]
                if cod_ver == 'Servico' or cod_ver =='Servigo':
                  cod_ver == None
                else:
                  pass
            if 'N° NFS' in line:
              na_prox = True
              
            if 'Tributagao no municipio' in line:
              if data == 'Codigo':
                data = line.split(' ')[3]
                cod_ver = line.split('|').replace(' ','')[0:6]
           
          print(data,cnpj_prestador,cnpj_tomador,valor,n_nota,cod_ver,image)
      except:
        pass
# Out:
# 20/11/2023 48.750.524/0001-26 41.248.067/0001-27 13.320,00 00000015 GVRV-LGDR AAC.jpg
# 20/11/2023 48.750.524/0001-26 41.248.067/0001-27 13.320,00 00000015 GVRV-LGDR AAC_AUGUSTO.jpg
# 08/11/2023 05.535.402/0001-04 41.248.067/0005-50 198,91 00040266 9UCQ-ZAJG ATAK.jpg
# Codigo 05.535.402/0001-04 41.248.067/0005-50 198,91 00040266 None CENTURY_MACEIO.jpg
# 24/11/2023 21.053.554/0001-27 41.248.067/0004-70 250,00 00000205 Servico NS INFORMATICA PETROLINA.jpg
# 24/11/2023 21.053.554/0001-27 41.248.067/0004-70 250,00 00000205 Servico NS INFORMATICA_ARAPIRACA.jpg
# 24/11/2023 21.053.554/0001-27 41.248.067/0004-70 250,00 00000205 Servico NS INFORMATICA_MATRIZ.jpg
# 24/11/2023 47.866.934/0001-74 41.248.067/0003-99 250,00 MUNICIPIO None VANCOUVER_SERV_22_11_2023.jpg

# %%
path = r'C:/Program Files/Tesseract-OCR'
imagem = cv2.imread(r"C:/Users/jvict/Documents/seven/seven/[05230009002822]LOJA28ENERGISA.jpg")
pytesseract.pytesseract.tesseract_cmd = path + r'/tesseract.exe'
texto = pytesseract.image_to_string(imagem)

print(texto)
# Out:
# G 174743- Abril/2021
#
# @enercaisa
#
# ROTEIRO: 007 - 0006 - 504 - 4460
# MATRICULA: 42467-2023-11-8
#
# DOM. BANC.:
#
# DOM. ENT:
#
# Classificago: MTC-CONVENCIONAL BAIXA TENSAO / B3
#
# COMERCIAL / OUTROS SERVICOS E OUTRAS ATIVIDADES
#
# LIGAGAO: TRIFASICO
#
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min.: 380 Lim. Max.: 399
# COMERCIAL DRUGSTORE LTDA
# AV PRES EPITACIO PESSOA, 402 - 8040000 CODIGO DO CLIENTE
# TORRE 5/42467-1
# JOAO PESSOA (AG: 1)
# CODIGO DA INSTALAGAO
#
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX8-22_
# Insc. Est.: 161XXXXXX W7034801514
#
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
#
# Novembro / 2023 26/12/2023 R$ 5.626,69
#
# Data de Apresentagao: 20/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# Utilize 0 Cédigo: 0000042467-1
# Lei Leit 2
# pc
# Datas de Leitura
# Leituras | 44/10/2023 13/11/2023 33 13/12/2023
#
# NOTA FISCAL N°: 002.128.740 - Série: 002
# DATA DE EMISSAO:14/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov.brinf3e/consulta
# chave de acesso:
#
# 2523 1109 0951 8300 0140 6600 2002 1287 4010 7194
# 1770
#
# Protocolo de Autorizacao:
# 32523000216087117 - 14/11/2023 13:45:00
#
# ~"Problemas com alcoolismo? Nés podemos ajudar — Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) Pis/ Base Calc. % Aliq. icms Tarifa) Base de Aliquota Valor
# Hens da Fatura Unid. Quant. comtributos Valor (R$) COFINS (R$) _ICMS (R$) ICMS. (RS) Unit (Rs) | Tuto Calc(R$)__(%) (RS)
# Consumo em kWh KWH 6.82600 0,770370 5.25859 201,50 5.25859. 18 946,54 0,602190 one ee ee ae
#
# LANCAMENTOS E SERVIGOS aa :
# CONTRIB SERV.ILUM.PUBLICA 368,10 0,00 000 0 0,00 IMS i
#
# Ne DIAS
#
# CONSUMO FATURADO FAT
# \ov23 28
# ur 33
# E123 29
# 02 28
# Uw 28
# Nn 33
# 23 31
# A823 as 29
# VAR 23 32
# V3 30
# N23 33
# 0222 29
# V2? 29
#
# TOTAL: 5.62669 201,50 5.258,59 946,54
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior tual Medidor kWh
# W7034801514 Energia ativa em kWh Ponta 222466 229292 1 6826 Art. 13, Inciso VII do RICMS/PB - 1997
#
# MATRICULA
# 42467-2023-11-8
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# VENCIMENTO
# 26/12/2023
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# N° FATURA
# 2128740
#
# TOTAL A PAGAR
# R$ 5.626,69

# %%
def remove_jpg_files(folder_path):
    try:
        # List all files in the specified folder
        files = os.listdir(folder_path)

        # Filter and remove JPG files
        for file in files:
            if file.lower().endswith(".jpg"):
                file_path = os.path.join(folder_path, file)
                os.remove(file_path)
                print(f"Removed: {file_path}")

        print("JPG files removed successfully.")
    
    except Exception as e:
        print(f"Error: {e}")

# Replace 'your_folder_path' with the actual path of the folder containing the JPG files
folder_path = r"C:\Users\jvict\Documents\seven\seven"
remove_jpg_files(folder_path)
# Out:
# Removed: C:\Users\jvict\Documents\seven\seven\[05230009002822]LOJA28ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[05230009002822]LOJA28ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[05230009002822]LOJA28ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000139]LOJA17ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000139]LOJA17ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000139]LOJA17ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000724]LOJA33ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000724]LOJA33ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000724]LOJA33ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619001704]LOJA31ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619001704]LOJA31ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619001704]LOJA31ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619002000]LOJA42ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619002000]LOJA42ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619002000]LOJA42ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619003740]LOJA60ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619003740]LOJA60ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619003740]LOJA60ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619004711]LOJA 36CELPE.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619004711]LOJA 36CELPE.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619004711]LOJA 36CELPE.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619005106]LOJA 38EQUATORIAL.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619005106]LOJA 38EQUATORIAL.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006170]LOJA74ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006170]LOJA74ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006170]LOJA74ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006250]LOJA65ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006250]LOJA65ENERGISA.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006250]LOJA65ENERGISA.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619008547]LOJA151CELPE.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619008547]LOJA151CELPE.jpg0001-1.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619008547]LOJA151CELPE.jpg0001-2.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619009608]LOJA163CELPE.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619009608]LOJA163CELPE.jpg0001-1.jpg
# Error: [WinError 32] O arquivo já está sendo usado por outro processo: 'C:\\Users\\jvict\\Documents\\seven\\seven\\[06198619009608]LOJA163CELPE.jpg0001-2.jpg'

# %%
data,cnpj_prestador,cnpj_tomador,valor,n_nota,cod_ver,image
