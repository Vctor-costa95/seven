# %%
from pdf2image import convert_from_path
import pytesseract
import cv2
import os
import temp
import shutil
from os import listdir, path, remove, unlink, walk

# %%
dir = r"C:/Users/jvict/Documents/seven/teste equatori"
fileExt = r".pdf"
for foto in os.listdir(dir):
    if (foto.endswith(fileExt)):
        diret = f"{dir}\{foto}"
        print(foto)
        nome = foto.replace('.pdf','')+'.jpg'
        images = convert_from_path(pdf_path= diret, poppler_path=r"C:\Program Files\poppler-23.11.0\Library\bin", fmt= 'jpg',output_file= nome)
        
        path = r'C:/Program Files/Tesseract-OCR'
        images[0].save(nome)
# Out:
# [05230009002822]LOJA28ENERGISA.pdf
# [06198619000139]LOJA17ENERGISA.pdf
# [06198619000724]LOJA33ENERGISA.pdf
# [06198619001704]LOJA31ENERGISA.pdf
# [06198619002000]LOJA42ENERGISA.pdf
# [06198619003740]LOJA60ENERGISA.pdf
# [06198619004711]LOJA 36CELPE.pdf
# [06198619005106]LOJA 38EQUATORIAL.pdf
# [06198619006170]LOJA74ENERGISA.pdf
# [06198619006250]LOJA65ENERGISA.pdf
# [06198619008547]LOJA151CELPE.pdf
# [06198619009608]LOJA163CELPE.pdf

# %%
fileExt = r".jpg" 
for image in os.listdir(r"C:\Users\jvict\Documents\seven\seven"):
    if image.endswith(fileExt) or image.endswith('JPG') :
          pytesseract.pytesseract.tesseract_cmd = path + r'/tesseract.exe'
          texto = pytesseract.image_to_string(image)
          #print(images)
          #print(texto)
          lines = texto.split('\n')
          d_h = False
          p_s = False
          na_prox = False
          pls= False
          cod_ver = None
          for line in lines:
            if d_h == True:
              data = line.split(' ')[6]
              try: 
                  int(data.replace(':','').replace('/',''))
              except:
                data = line.split(' ')[7]
                try: 
                  int(data.replace(':','').replace('/',''))
                except:
                  data = line.split(' ')[0]
              d_h = False
              
            if p_s == True:
              cnpj_prestador = line.replace(' ','').split(':')[1][0:18]
              p_s = False
            if 'Data e Hora' in line:
              d_h = True
              
            if 'PRESTADOR DE SERVICOS' in line:
              p_s = True
              
            if 'CPF/CNPJ:' in line:
              cnpj_tomador = line.split(' ')[1]
              
            if 'VALOR TOTAL DO SERVICO' in line:
              valor = line.split(' ')[6]
              
            if 'PREFEITURA DO' in line:
              n_nota= line.split(' ')[2]
              
            if 'Nota Fiscal de' in line:
                cod_ver = line.split(' ')[-1]
                if cod_ver == 'Servico' or cod_ver =='Servigo':
                  cod_ver == None
                else:
                  pass
            if 'N° NFS' in line:
              na_prox = True
              
            if 'Tributagao no municipio' in line:
              if data == 'Codigo':
                data = line.split(' ')[3]
                cod_ver = line.split('|').replace(' ','')[0:6]
           
#print(data,cnpj_prestador,cnpj_tomador,valor,n_nota,cod_ver,image)
# Out:
# G 174743- Abril/2021
#
# @enercisa
#
# ROTEIRO: 007 - 0006 - 504 - 4460
# MATRICULA: 42467-2023-11-8
#
# DOM. BANC.:
#
# DOM. ENT:
#
# Classificago: MTC-CONVENCIONAL BAIXA TENSAO / B3
#
# COMERCIAL / OUTROS SERVICOS E OUTRAS ATIVIDADES
#
# LIGAGAO: TRIFASICO
#
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min.: 380 Lim. Max.: 399
# COMERCIAL DRUGSTORE LTDA
# AV PRES EPITACIO PESSOA, 402 - 8040000 CODIGO DO CLIENTE
# TORRE 5/42467-1
# JOAO PESSOA (AG: 1)
# CODIGO DA INSTALAGAO
#
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX8-22_
# Insc. Est.: 161XXXXXX W7034801514
#
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
#
# Novembro / 2023 26/12/2023 R$ 5.626,69
#
# Data de Apresentagao: 20/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# Utilize 0 Cédigo: 0000042467-1
# Lei Leit x6
# — or | poe
# Datas de Leitura
# Leituras | 44/10/2023 13/11/2023 33 13/12/2023
#
# NOTA FISCAL N°: 002.128.740 - Série: 002
# DATA DE EMISSAO:14/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov.brinf3e/consulta
# chave de acesso:
#
# 2523 1109 0951 8300 0140 6600 2002 1287 4010 7194
# 1770
#
# Protocolo de Autorizacao:
# 32523000216087117 - 14/11/2023 13:45:00
#
# ~"Problemas com alcoolismo? Nés podemos ajudar — Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) Pis/ Base Calc. % Aliq. icms Tarifa} Base de Aliquota Valor
# Hens da Fatura Unid. Quant, comtributos Valor (R$) COFINS (R$) _ICMS (R$) ICMS. (RS) Unit (Rs) | TbUte Calc(R$)_—_(%) (RS)
# Consumo em kWh KWH 6.82600 0,70370 5.25859 201,50 5.258,59. 18 946,54 0,602190 one ee ee ae
#
# LANCAMENTOS E SERVIGOS aa :
# CONTRIB SERV.ILUM.PUBLICA 368,10 0,00 000 0 0,00 sus ne
#
# Ne DIAS
#
# CONSUMO FATURADO FAT
# \ov23 28
# ur 33
# E123 29
# 02 28
# Uw 28
# Nn 33
# 23 31
# A823 as 29
# VAR 23 32
# V3 30
# N23 33
# 0222 29
# V2? 29
#
# TOTAL: 5.62669 201,50 5.258,59 946,54
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior Atual Medidor kWh
# W7034801514 Energia ativa em kWh Ponta 222466 229292 1 6826 Art. 13, Inciso VII do RICMS/PB - 1997
#
# MATRICULA
# 42467-2023-11-8
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# VENCIMENTO
# 26/12/2023
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# N° FATURA
# 2128740
#
# TOTAL A PAGAR
# R$ 5.626,69
#
#
# G 174743- Abril/2021
#
# ROTEIRO: 013 - 0013 - 301 - 4980
# MATRICULA: 1307383-2023-11-5
#
# DOM. BANC.:
#
# Classificagao: MTC-CONVENCIONAL BAIXA TENSAO / B3
# COMERCIAL / OUTROS SERVIGOS E OUTRAS ATIVIDADES
#
# DOM. ENT:
#
# LIGAGAO: TRIFASICO
#
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min: 350 Lim. Max.: 399
# DROGATIM DROGARIAS LTDA
# RUA MAR VERMELHO, SIN - 58100001 CODIGO DO CLIENTE
# INTERMARES 5/1307383-8
# CABEDELO (AG: 1)
# CODIGO DA INSTALAGAO
#
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX5-01
# Insc. Est.: 162XXXXXX W7024683513
#
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
#
# Novembro / 2023 26/12/2023 R$ 4.778,63
#
# Data de Apresentacaéo: 28/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# Utilize 0 Codigo: 0001307383-8
# — or | poe
# Datas de Leitura
# Leituras | 23/10/2023 22/11/2023 30 21/12/2023
#
# NOTA FISCAL N°: 002.185.792 - Série: 002
# DATA DE EMISSAO:23/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov.brinf3e/consulta
# chave de acesso:
#
# 2523 1109 0951 8300 0140 6600 2002 1857 9210 0892
# 7230
#
# Protocolo de Autorizagao:
# 32523000223 18532 - 23/11/2023 14:12:05,
#
# ~"Problemas com alcoolismo? Nés podemos ajudar—Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) PIs! Base Calc. % Aliq. icms Tarifa} Base de Aliquota Valor
# Hens da Fatura Unid. Quant. comtributos Valor (R$) COFINS (R$) ICMS (R$) ICMS. (RS) Unit (Rs) | TbUte Calc(R$)_—_(%) (RS)
# Consumo em kWh KWH 5.85200 _0,70370 427713 163,90 427713 18 769,88 0,602190 one ae ee ie
#
# LANCAMENTOS E SERVIGOS an ;
# CONTRIBUIGAO ILUM PUBLICA 501,50 0,00 0,00 0 0,00 see. SS bia
#
# Ne DIAS
#
# CONSUMO FATURADO FAT
# v2) 32
# uu? 3
# SET?) 31
# Aco723 28
# Uw 29
# JN? 3t
# 2 32
# R23 29
# R23 30
# V3 as 32
# N23 30
# 0222 32
# v2? 29
#
# TOTAL: 4.77863 163,90 A2TTAS 769,88
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior Atual Medidor kWh
# W7024683513 Energia ativa em kWh Ponta 167458 173010 1 5552 ‘Art. 13, Inciso VII do RICMSIPB - 1997
#
# MATRICULA
# 1307383-2023-11-5
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# N° FATURA
# 2185792
#
# VENCIMENTO
# 26/12/2023
#
# TOTAL A PAGAR
# R$ 4.778,63
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# G 174743- Abril/2021
#
# @enercisa
#
# ROTEIRO: 007 - 0006 - 548 - 7340
# MATRICULA: 41828-2023-11-2
#
# Data de Apresentagao: 20/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# DOM. BANC.: DOM. ENT:
# Utilize o Codigo: 0000041828-5
# Classificagdo: MTC-CONVENCIONAL BAIXA TENSAO / B3
# COMERCIAL / OUTROS SERVICOS E OUTRAS ATIVIDADES LIGAGAO: TRIFASICO
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min.: 350 Lim. Max.: 399 Leitura Leitura N° Dias piesa
# Anterior Atual 2
# Datas de Leitura
# DROGATIM DROGARIAS LTDA Leituras | 44/40/2023 13/11/2023 33 13/12/2023
# ‘AV MIN JOSE AMERICO DE ALMEIDA, 573 - 58040300 CODIGO DO CLIENTE
# TORRE 5/41828-5 NOTA FISCAL N°: 002.128.738 - Série: 002
# JOAO PESSOA (AG: 1) DATA DE EMISSAO:14/11/2023
# CODIGO DA INSTALAGAO
# Consulte pela Chave de Acesso em:
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX7-24
# ieee eRe ORs 'W7030620311 hanes fe were sare cox retlconails
# 2523 1109 0951 8300 0140 6600 2002 1287 3810 4938
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR A545
# Protocolo de Autorizacao:
# Novembro / 2023 26/12/2023 R$ 5.427,21 S25 250002) 608 (0/11 202351233500)
#
# ~"Problemas com alcoolismo? Nés podemos ajudar — Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) PIS/ Base Calc. % Alig. cms Tarifa} Base de Aliquota Valor
# Itens da Fatura Unid. Quant. comtributos Valor (R$) COFINS (R$) ICMS (R$) ICMS (RS) Unit (Rs) | Tuto Cale(RS) — (%) (R8)
# Consumo em kWh KWH 6.584,00 _0,70370 5.07216 194,36 5.07216 18 912,98 0,602190 one ; He ee eee
#
# LANCAMENTOS E SERVIGOS n18 3 ;
# CONTRIB SERV.ILUM.PUBLICA 355,05 0,00 000 0 0,00 sous Bore16 18.00 812.88
#
# Ne DIAS
#
# CONSUMO FATURADO FAT
# 0V23 28
# uu? 33
# st? 29
# 0? a 28
# Uw 28
# JN? 33
# Al) 31
# A823 as 29
# VAR 23 32
# V2 30
# AN 33
# 0222 29
# v2? 29
#
# TOTAL: 5.427,21 194,36 5.072,16 912,98
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior Atual Medidor kWh
# W7030620311 Energia ativa em kWh Ponta 191969 198583 1 6584 Art. 13, Inciso VII do RICMS/PB - 1997
#
# MATRICULA
# 41828-2023-11-2
#
# t
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA N° FATURA
# 2128738
# VENCIMENTO TOTAL A PAGAR
# 26/12/2023 R$ 5.427,21
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# DANF3E - DOCUMENTO AUXILIAR DA NOTA FISCAL
# DE ENERGIA ELETRICA ELETRONICA
#
# >)
# Qenercisa
#
# Classificagéo: MTC-CONVENCIONAL BAIXA TENSAO / B3 Tipo de Fornecimento: TRIFASICO
# COMERCIAL/COMERCIAL,
# ‘TENSAO NOMINAL EM VOLTS Disp: 220 Lim. min.: 202 Lim. max.: 231
#
# DROGATIM DROGARIAS LTDA
#
# CODIGO DO CLIENTE
#
# RUAPROFALUIZAMEDEIROS Si BOXAFARMAGIA-VOSE ANERICO
# ep saraoun TONS pEeSoN PSG S 5/2662307-4
#
# Roteiro: 05-0005-425-3110 CODIGO DA INSTALACAO
#
# 'W7070407083
#
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
# DEZ/2023 18/12/2023 R$ 4.326,28
#
# NOTA FISCAL N° 25167781 - SERIE :001
#
# DATA EMISSAO/APRESENTACAO: 11/12/2023
# Consulte pela Chave de Acesso em
# hhttps://dfe-portal.svrs.rs.gov.brinfSe/consulta
#
# Chave de Acesso
# 2523 1209 0951 8300 0140 6600 1025 1677 8120 5689 2993
#
# EMITIDO EM CONTINGENCIA.
# Pendente de Autorizacao
#
# Leitura Leitura Préxima
# Anterior Atual ro
#
# Datas de
# Leituras 09/11/2023 11/12/2023 10/01/2024
# IcMS Tarifa
# Total (Rs) unit.
# ITENS DA FATURA Unid. Quant (RS) 425) ARS) £%) (RS)
# ‘Consumo em kWh KWH, 58228 0.773670 4043.26 | 168,43 4.043.260 18 «727,78 0.602190
# LANGAMENTOS & SERVIGOS
# ‘CONTRIB SERV.ILUM.PUBLICA 283,02] 0,00 000 «0 (000
# TOTAL: 432628 | 168,43 404326, 727,78
# Spar nba tela east ||| are Basede  Aliquota_—_Valor (RS)
# eze2 + 33 Chile. (RS) (%)
# ANZ 2B
# revs | 29 PISIPASEP 3.315,47 0,9062 30,04
# = RS 3 COFINS —3.315,47 41741 138,39
# Pe v2 saz 30 cms 4,043,26 18,00 727,78
# 2 i732 30
# = ee _ 2496 31
# Fe co —— 2055 30,
# a oo — as 30 RESERVADO AO FISCO
# = ———t 420 30 EMITIDO EM CONTINGENCIA
# —_— 230 Pendente de Autorizacao
# * Faturamento pla médialminimo
# Medidor Grandezas Postos Leitu Leitura Const Consumo
# hordrios Anterior Atual — Medidor kWh
# w7070407083 kWh Total 19803 250291 5226
#
# Situacao de Débitos FATURAS EM ATRASO
#
# CADASTRE SUA FATURA EM DEBITO AUTOMATICO UTILIZANDO O CODIGO: 00026623074
# Esta NOTA FISCALICONTA DE ENERGIA fica disponivel para pagamento a partir de 11/12/2023
#
# ESTA FAT. SERA DEBIT. NO BCO 0356
#
# PAGADOR:DROGATIM DROGARIAS LTDA CNPJI/CPF: 06.198.619/0017-04
# RUA PROFA LUIZA MEDEIROS SN BOX A FARMACIA - JOSE AMERICO - JOAO PESSOA/ PB - CEP 58073040
# Nosso-Numero Nr Documento Data de Vencimento] Valor do Documento | Valor Pago
# 2662307-2023-12-9 19/12/2023 | 4326,28
#
# BENEFICIARIO:ENERGISA PARAIBA DISTRIBUIDORA DE ENERGIASA —_09.095.183/0001-40
# BR230 KM 25, SN- - CRISTO REDENTOR - JOAO PESSOA/ PB - CEP 58071-680
#
# Agéncia / Codigo do Beneficiario:2938/59511-9
#
# PAGUE POR oseceredosovtance
#
# @selecione "PIX’.
#
# nte a camera
# Opera eae
# ‘@Confirme o pagamento.
#
#
# G 174743- Abril/2021
#
# ROTEIRO: 007 - 0006 - 604 - 6060
# MATRICULA: 41588-2023-11-2
#
# DOM. BANC.:
#
# Classificagao: MTC-CONVENCIONAL BAIXA TENSAO / B3
# COMERCIAL / OUTROS SERVIGOS E OUTRAS ATIVIDADES
#
# DOM. ENT:
#
# LIGAGAO: TRIFASICO
#
# TENSAO NOMINAL EM VOLTS _ DISP: Lim. Min.: 350 Lim. Max.: 399
# DROGATIM DROGARIAS LTDA
# AV PRES EPITACIO PESSOA, 1648 - 58040000 CODIGO DO CLIENTE
# TORRE 5/41588-5
# JOAO PESSOA (AG: 1)
# CODIGO DA INSTALAGAO
# CNPJ/CPFIRANI: OX.XXX.XXX/XXX0-00
# Insc. Est: 161XXXXXX W7026739311
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
# Novembro / 2023 21/12/2023 R$ 3.659,07
#
# Data de Apresentacaéo: 20/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# Utilize 0 Codigo: 0000041588-5
# — or | poe
# Datas de Leitura
# Leituras | 44/40/2023 13/11/2023 33 13/12/2023
#
# NOTA FISCAL N°: 002.128.723 - Série: 002
# DATA DE EMISSAO:14/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov.brinf3e/consulta
# chave de acesso:
#
# 2523 1109 0951 8300 0140 6600 2002 1287 2310 8963,
# 7975
#
# Protocolo de Autorizagao:
# '3252300021608758 - 14/11/2023 13:45:01
#
# ~"Problemas com alcoolismo? Nés podemos ajudar—Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) PIs! Base Calc. % Aliq. icms Tarifa} Base de Aliquota Valor
# Hens da Fatura Unid. Quant. comtributos Valor (R$) COFINS (R$) ICMS (R$) ICMS. (RS) Unit (Rs) | TbUte Calc(R$)_—_(%) (RS)
# Consumo em kWh KWH 4.439,00 —_0,770370 3.419,70 131,03 3.419,70 18 615,54 0,602190 one Be ee eae!
#
# LANCAMENTOS E SERVIGOS an ‘
# CONTRIB SERV.ILUM.PUBLICA 239,37 0,00 0,00 0 0,00 see. Ae eee
#
# Ne DIAS
#
# CONSUMO FATURADO FAT
# Nov23 28
# ouri23 33
# SE?) 29
# 0) a 28
# Uw 28
# JN? 33,
# 2 31
# ARR23 as 29
# VAR23 32
# V3 30
# AN 33
# 22? 29
# v2? 29
#
# TOTAL: 3.659,07 131,03 3.419,70 615,54
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior Atual Medidor kWh
# W7026739311 Energia ativa em kWh Ponta 161291 165736 1 4439 ‘Art. 13, Inciso VII do RICMSIPB - 1997
#
# MATRICULA
# 41588-2023-11-2
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# N° FATURA
# 2128723
#
# VENCIMENTO
# 21/12/2023
#
# TOTAL A PAGAR
# R$ 3.659,07
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# G 174743- Abril/2021
#
# @enercisa
#
# ROTEIRO: 008 - 0005 - 290 - 0810
# MATRICULA: 406381-2023-11-1
#
# DOM. BANC.:
#
# Classificago: MTC-CONVENCIONAL BAIXA TENSAO / B3
# COMERCIAL / OUTROS SERVICOS E OUTRAS ATIVIDADES
#
# DOM. ENT:
#
# LIGAGAO: TRIFASICO
#
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min.: 380 Lim. Max.: 399
# DROGATIM DROGARIAS LTDA
# RUA JOSEFA TAVEIRA, 11 - 1171 B - 58000000 CODIGO DO CLIENTE
# MANGABEIRA 5/406381-4
# JOAO PESSOA (AG: 5)
# CODIGO DA INSTALAGAO
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX7-40_
# Insc. Est.: 161XXXXXX 00008911713
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
# Novembro / 2023 26/12/2023 R$ 4.912,85
#
# Data de Apresentagao: 21/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# Utilize 0 Cédigo: 0000406381-4
# Leitt Leit x6
# — or | poe
# Datas de Leitura
# Leituras | 46/10/2023 14/11/2023 29 14/12/2023
#
# NOTA FISCAL N°: 002.143.010 - Série: 002
# DATA DE EMISSAO:16/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov.brinf3e/consulta
# chave de acesso:
#
# 2523 1109 0951 8300 0140 6600 2002 1430 1010 9792
# 2614
#
# Protocolo de Autorizagao:
# 3252300021757725 - 16/11/2023 17:04:12
#
# ~"Problemas com alcoolismo? Nés podemos ajudar — Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) PIS/ Base Calc. % Alig. cms Tarifa} Base de Aliquota Valor
# Itens da Fatura Unid. Quant. comtributos Valor (R$) COFINS (R$) ICMS (R$) ICMS. (RS) Unit (Rs) | TPUto Calc(R$)_—_(%) (RS)
# Consumo em kWh KWH 5.960,00 _0,770370 4.59145 175,98 4591.45 18 826,46 0,602190 one wis ee ae
#
# LANGAMENTOS E SERVIGOS 8833 ;
# CONTRIB SERVILUM.PUBLICA 321,40 0,00 000 0 0,00 sous Aba}A, 18,00 826.86
#
# Ne DIAS.
#
# CONSUMO FATURADO FAT
# NV 23 32
# Ou? 3
# S123 31
# 0) a 28
# U2 28
# JN? 32
# V2) 32
# A823 as 29
# R23 30
# V3 as 32
# AN? 3t
# C22? 31
# V2? 29
#
# TOTAL: 491285 175,93 4.59145 826,46
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior tual Medidor = kWh
# 00008911713 Energia ativa em kWh Ponta 377921 383881 1 5960 Art. 13, Inciso VII do RICMS/PB - 1997
#
# MATRICULA
# 406381-2023-11-1
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# VENCIMENTO
# 26/12/2023
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# N° FATURA
# 2143010
#
# TOTAL A PAGAR
# R$ 4.912,85
#
#
# @ Neoenergia
#
# Pernambuco
#
# DANFE - DOCUMENTO AUXILIAR DA NOTA FISCAL DE ENERGIA ELETRICA ELETRONICA
#
# COMPANHIA ENERGETICA DE PERNAMBUCO
#
# 4
#
# AV.JOAO DE BARROS, 111, BOA VISTA, RECIFE, PERNAMBUCO CEP 50050-902
# neoenergiapernambuco.com.briLigue gratis 116 CNPJ 10.835.932/0001-08 INSCRIGAO ESTADUAL 0005943-93
#
# Tarifa Social de Energia Elétrica - Lei 10.438, de 26/04/02
#
# NOME DO CLIENTE:
#
# DROGATIM DROGARIAS LTDA DROGAVIVO. CODIGO DA INSTALAGAO
#
# CNPJ: 06.198.619/0047-11
#
# ENDEREGO: 2646122
#
# ET DOS REMEDIOS 94
#
# AFOGADOS/RECIFE CODIGO DO CLIENTE
#
# 50770-120 RECIFE PE 7050687311
# REF:MES/ANO TOTAL A PAGAR RS VENCIMENTO
# 11/2023 1.218,49 18/12/2023
#
# NOTA FISCAL N° 285025005 - SERIE 000 / DATA DE EMISSAO: 01/12/2023
# Consulte pela Chave de Acesso em:
#
# https://dfe-portal.svrs.rs.gov. briNf3e/consulta
#
# chave de acesso:
#
# 2623 1210 8359 3200 0108 6600 0285 0250 0510 3815 2829
#
# Protocolo de autorizago: 3262300044435676 - 01/12/2023 as 17:03:14
#
# CLASSIFICAGAO: B3 COMERCIAL -COMERCIAL
#
# TIPO DE FORNECIMENTO: Conv. Monémia - Trifasico
#
# Cadastra-se e receba a sua fatura por e-mail, utilizando o QR code no verso da fatura.
#
# DATAS DE LEITURAS LEITURA ANTERIOR 25/10/2023 LEITURA ATUAL 25/11/2023 N°DEDIAS 31 PROXIMA LEITURA 26/12/2023
# ITENS DA FATURA UNID. QUANT. IPRECO UNIT. VALOR PIS/ BASE CALC. |ALIQUOTA| ICMS (R$) TARIFA |TRIBUTO| BASE DE juiauora] VALOR (R$)
# COM TRIB.(RS)| (R$) COFINS(R$) ICMS(R$) ICMS(%) UNIT(RS) CALCULO (RS)| _(%)
# \Consumo-TUSD kWh 885,31] 0,54941336 486,40 22,26 486,40| 18,00 87,55] 0,42538000}| P'S MezB) = 9.88 a8,
# \Consumo-TE kWh 885,31] 0,43796270 387,73 17,73 387,73} 18,00 69,79] 0,33909000}] COFINS M78) 488 S200.
# lllum. Pub. Municipal 53,04 Jems 874,13) 18,00: 18734
# IICMS-CDE NF276666402 18,82
# jurosCOSIP 1,10
# IPCACOSIP 0,36
# IMulta-NF 276666402 78,10 CONSUMO | kWh
# IMulta-NF 272421127 97,98 CONSUMO FATURADO _N'DIAS FAT
# Luros-NF 272421127 76,74 Nove3 885 31
# Lluros-NF 276666402 18,22 eal ‘ie a5
# SET23 = 4014 32
# a
# AGO23 |) 5009 35
# JUL23
# JUN23
# MAI23,
# ABR23
# MAR23
# FEV23
# JAN23
# DEZ22
# [TOTAL 1.218,49 Novz2
# MEDIDOR GRANDEZAS POSTOS LEITURA LEITURA. CONST. CONSUMO RESERVADO AO FISCO
# HORARIOS. ANTERIOR ATUAL MEDIDOR kWh Cobranga ICMS sobre subvengao CDE, conforme Decreto Estadual 39.459/13.
# 3212681708 | Energia Ativa Unico 92.295,00 97.531,00 1,00000 885,31
# 3212681708 | Energia Reativa Unico 41.744,00 43.595,00 1,00000 1.851,00
#
# é a emissdo desta fatura vocé nao
#
# ossui débitos para esse cédii
#
# es go de cliente.Parabéns por manter suas contas em dia! Cont
# mpre com a gente. Este comunicado nao contempla débitos em discussao judicial.A compensagao do pagamento ocorrera e'
# ité 3 dias uteis, apds data do pagamento.
#
# INFORMAGOES IMPORTANTES
#
# Na data da'leitura a bandeira em vigor & a Verde. Mais informagdes em www.aneel.gov.br.
# No valor do consumo faturado esta inclufdo o ajuste na(s) fun¢ao(des) CAT de - 4350.69 kWh
# Unidade integrante de sistema de compensacao. Total de credi tos utilizados na unidade: 4350,69483 kWh
#
# copico bo ciente 7050687311
#
# vENcIMENTO 18/12/2023
#
# TOTAL A PAGAR R$ 1.218,49
#
# 11/2023
#
# PARA CADASTRAR SUA CONTA EM DEBITO AUTOMATICO, UTILIZE O CODIGO DO CLIENTE.
#
# Pagamento através de Débito Automatico em Conta Corrente.
#
# anco 033-7 Agéncia 3737
#
# Como gébito automatico sua conta fica sempre em dia. Vocé pode
#
# solicitar o cancelamento do servico a qualquer momento.
# Para mais informagoes ligue 11
#
#
# DANFSE - DOCUMENTO AUXILIAR DA NOTA FISCAL DE ENERGIA ELETRICA ELETRONICA 2" Via
#
# Equatorial Alagoas Distribuidora de Energia S.A. Pagina 1/1
# Bomateanial cup. 12.272.084/0001-00 | Insc. Estadual: 24.007.177-8
# ean LR ee Av. Fernandes Lima, 3349
# Gruta de Lourdes - Maceié - AL CEP: 57.052-902
# Classificagao: Comercial Tipo de Fornecimento: TRIFASICO
#
# Tensao Nominal Disp: 380V Lim Min: V__ Lim Max: V
#
# Data das | Leitura Anterior | Leitura Atual N° de Dias | Proxima Leitura
#
# DROGATIM DROGARIAS LTDA Leituras | 27/10/2023 28/11/2023 32 28/12/2023
# INSTALACAO: 12439622 Parceiro de Negécio
#
# CNPU: **."**.619/005*-"* [a] , .
#
# AV ALVARO OTACILIO , 367 , 4187 LJ 0001 CEP: 18624170 NOTA FISCAL N° 024380380 - SERIE 000 /
#
# DATA DE EMISSAO: 30/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov. br/NF3E/Consulta
#
# chave de acesso:
# 27231112272084000100660000243803801059248349
# Conta Més Vencimento Total a Pagar BeBe" Protocolo de autorizacao: 3272300014926845 -
#
# 11/2023 14/12/2023 R$ 10.603,71
#
# 57035-180 JATIUCA - MACEIO - AL.
#
# Conta Contrato
#
# 200313087
#
# INFORMACOES PARA O CLIENTE.
# '® Periods: Band. Tarif.: Verde : 28/10 - 28/11
#
# Itens de Fatura Quant. Prego Unit.(R$) Tarifa PIS/ ICMS. Valor(R$) Tributo Base(R$) Aliquota(%) Valor(R$)
# comTributos _Unit(R$)___ COFINS(R$) (R$) ToMS 10.238,42 21,0000 2.15007
# Consumo (kWh) 8.713 1175074 0,866020 542,73 2.150,07 10.238,42 || pis 8.088,35 1.1954 96,69
# COFINS 8.088,35 5.5146 446,04
# ITENS FINANCEIROS
# Cip-llum Pub Pref Munic 365,29
# NOV/22 | 0
# DEZ/22 | 0
# C| JAN/23 | 0
# “ FEV/23 | 0
# S| MAR/23 | 0
# | ABRI23 | 0
# O} MAI/23 | 0
# JUN/23, ( 7565
# ‘ JUL/23 7513
# h | AGO/23 (— 8006
# SET/23 7789
# OUT/23 9266
# NOV/23 8713
# ative
# Medidor Grandeza Posto Hordrio Leitura Leitura] Const ‘Consumo Reservado ao Fisco
# Anterior Atual Medidor
# 3244005 Consumo ATIVO TOTAL 2.761 Tara 7,00 8.713 kWh 55E0.6517.5009.DBC3.71B0.25F8.2863.F3F0
# Resolugao ANEEL ‘Apresentagao N° do Programa Social
# 3203/23 05/12/2023
# REAVISO DE VENCIMENTO.
# CENTRAL DE ATENDIMENTO Piabepeled sper ad ga
#
# LIGUE GRATIS 0800 082 01 96 ‘operant tiie
#
# AATENDIMENTO GRATUITO 24 H 0727 0167
#
# Giecuateraial”@ oequatoral st QeequatoratAL cional de Energia Elétrica (ANEEL) 167
#
# ds tellone fore
# DIREITOS
#
# E direito do consumidor ou da central geradora de solicitar 8 distribuidora o detalhamento da apuracso dos
# indicadores DIC, FIC, DMI e DICRI a qualquer tempo.
#
# E direito do consumidor ou da central geradora de receber uma compensacao, caso sejam violados os
# limites de continuidade individuais elativos 8 unidade consumidora ou central geradora.
#
# Pague através do PIX.
#
# CITIBANK 745-5] 74593.10046 26569.019024 17009.090808 2 95640001060371 .
#
# TOCAL DE PAGAMENTO VENCIMENTO E mais facilidade pra
# PAGAVEL NA REDE BANCARIA ATE O VENCIMENTO 14.12.2023 a
#
# BENEFICIARIO INSTALAGAO REFERENGIA "AGENCIAICODIGO BENEFIGIARIO voce.
#
# EQUATORIAL ALAGOAS DISTRIB. DE ENERGIA S.A. 12439622 11/2023 Para realizar o pagamento,
# DATA DOGUMENTO NUMERO DE REFERENCIA ESPECIE DOCUMENTO ACENE DATA PROCESSAMENTO NOSSO NUMERO
#
# 30.11.2023 0202311024380380 DMI N 30.11.2023 02170090908-0 utilize o QR CODE abaixo.
# USO DO BANCO ‘CARTERA ESPECIE MOEDA ‘QUANTIOADE VALOR (=) VALOR DOCUMENTS
#
# RCO 100 R$ 10.603,71
#
# INFORMAGOES DE RESPONSABILIDADE DO BENEFICIARIO SLDESDONTOABATIMENTS
#
# PAGAVEL EM TODAS AS INSTITUICOES BANCARIAS. ,
#
# EM CASO DE ATRASO, MULTAS, JOROS E CORRECAO SERAO COBRADOS NA PROXIMA FATURA. a
#
# NOME DO PAGADORICPFICNP.JENDERECO
# DROGATIM DROGARIAS LTDA 06.198.619/0051-06 Gy MULTA
#
# (+) OUTROS ACRESCIMOS:
# Ficha de Compensagao
#
#
# G 174743- Abril/2021
#
# @enercisa
#
# ROTEIRO: 010 - 0002 - 306 - 5320
# MATRICULA: 757477-2023-11-2
#
# DOM. BANC.:
#
# Classificago: MTC-CONVENCIONAL BAIXA TENSAO / B3
# COMERCIAL / OUTROS SERVICOS E OUTRAS ATIVIDADES
#
# DOM. ENT:
#
# LIGAGAO: TRIFASICO
#
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min.: 380 Lim. Max.: 399
# DROGATIM DROGARIAS LTDA
# AV VALDEMAR GALDINO NAZIAZENO, 920 - 58075000 CODIGO DO CLIENTE
# JOAO PAULO Il 5/757477-5
# JOAO PESSOA (AG: 1)
# CODIGO DA INSTALAGAO
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX1-70,
# Insc. Est.: 162XXXXXX W7030621201
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
# Novembro / 2023 26/12/2023 R$ 4.550,15
#
# Data de Apresentagao: 23/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# Utilize 0 Cédigo: 0000757477-5
# Lei Leit x6
# — or | poe
# Datas de Leitura
# Leituras | 48/10/2023 17/11/2023 30 18/12/2023
#
# NOTA FISCAL N°: 002.163.272 - Série: 002
# DATA DE EMISSAO:20/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov.brinf3e/consulta
# chave de acesso:
#
# 2523 1109 0951 8300 0140 6600 2002 1632 7210 5475,
# 2637
#
# Protocolo de Autorizagao:
# 32523000219727 16 - 20/11/2023 14:41:35
#
# ~"Problemas com alcoolismo? Nés podemos ajudar — Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) Pis/ Base Calc. % Aliq. icms Tarifa} Base de Aliquota Valor
# Hens da Fatura Unid. Quant, comtributos Valor (R$) COFINS (R$) _ICMS (R$) ICMS. (RS) Unit (Rs) | TbUte Calc(R$)_—_(%) (RS)
# Consumo em kWh KWH 5.620,00 0,70370 4.25248 162,95 4,252.48 18 765,44 0,602190 one ele ee ree
#
# LANGAMENTOS E SERVICOS ane ;
# CONTRIB SERV.ILUM.PUBLICA 297,67 0,00 0,00 0 0,00 sus i oe
#
# N° DIAS
#
# CONSUMO FATURADO FAT
# V2 30
# uu? 33
# 23 29
# 10023 28
# U2 29
# JN? 33
# 2 30
# ARR23 as 3
# 2 30
# Vi? 30
# N23 32
# 22? 30
# v2? a 29
#
# TOTAL: 4.55015 162,95 4.252,48 765,44
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horsrios Anterior tual Medidor kWh
# 7030621201 Energia ativa em kWh Ponta 196861 202381 1 5520 Art. 13, Inciso Vil do RICMS/PB - 1997
#
# MATRICULA
# 757477-2023-11-2
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# VENCIMENTO
# 26/12/2023
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# N° FATURA
# 2163272
#
# TOTAL A PAGAR
# R$ 4.550,15
#
#
# G 174743- Abril/2021
#
# @enercisa
#
# ROTEIRO: 003 - 0006 - 144 - 4920
# MATRICULA: 33470-2023-12-1
#
# Data de Apresentagao: 12/12/2023
# Cadastre sua Fatura em Débito Automatico.
#
# DOM. BANC.: DOM. ENT:
# Utilize o Codigo: 0000033470-6
# Classificagdo: MTC-CONVENCIONAL BAIXA TENSAO / B3
# COMERCIAL / OUTROS SERVICOS E OUTRAS ATIVIDADES LIGAGAO: TRIFASICO
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min.: 350 Lim. Max.: 399 Leitura Leitura N° Dias piesa
# Anterior Atual 2
# Datas de Leitura
# DROGATIM DROGARIAS LTDA Leituras | 97/11/2023 06/12/2023 29 08/01/2024
# RUATITO SILVA, 41 - C - 58043090 CODIGO DO CLIENTE
# IEAM 5/33470-6 NOTA FISCAL N°: 002.263.048 - Série: 002
# JOAO PESSOA (AG: 1) DATA DE EMISSAO:07/12/2023
# CODIGO DA INSTALAGAO
# Consulte pela Chave de Acesso em:
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX2-50_
# ieee DeReOneet 00008977978 hanes fe were sare cox retlconails
# 2523 1209 0951 8300 0140 6600 2002 2630 4810 7004
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR ee)
# Protocolo de Autorizacao:
# Dezembro / 2023 26/12/2023 R$ 4.232,74 Seb em 00292 ( (7005 Or aiai2s 101801
#
# -AEnergisa esta realizando um trabalho de otimizagao no processo_ de leitura. Para isso, podera ocorrer alteragao no ntimero de dias_de faturamento e no vencimento de sua fatura no proximo més. Duvidas, entre em
#
# contato com 0 0800 083 0196. -"Problemas com alcoolismo? Nés podemos ajudar — Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Andnimos na Paraiba
#
# Prego unit (R$) PIS/ Base Calc. % Alig. cms Tarifa} Base de Aliquota Valor
# Itens da Fatura Unid. Quant. comtributos Valor (R$) COFINS (R$) ICMS (R$) ICMS. (RS) Unit (Rs) | TPUto Calc(R$)_—_(%) (RS)
# Consumo em kWh KWH 5.11300 0,773670 3.95584 164,79 3.955,84 18 712,05 0,602190 one sok nee ee
#
# LANGAMENTOS E SERVIGOS SE ;
# CONTRIB SERVILUM.PUBLICA 276,90 0,00 000 0 0,00 sous BEEBE 18.00) Habs
#
# Ne DIAS.
#
# CONSUMO FATURADO FAT
# 22) 33
# ov?) 30
# un? 29
# a 31
# Aco?3 27
# vw 28
# UN? 32
# VA/23 33
# 23 28
# 23 31
# FV 23 33
# AN 33
# 22 30
#
# TOTAL: 4.232,74 164,79 3.955,84 712,05
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior tual Medidor = kWh
# 00008977978 Energia ativa em kWh Ponta 401476 406589 1 5113 Art. 13, Inciso VII do RICMS/PB - 1997
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# MATRICULA
# 33470-2023-12-1
#
# VENCIMENTO
# 26/12/2023
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
# NO BANCO 0356
#
# N° FATURA
# 2263048
#
# TOTAL A PAGAR
# R$ 4.232,74
#
#
# @ Neoenergia
#
# Pernambuco
#
# COMPANHIA ENERGETICA DE PERNAMBUCO
#
# DANFE - DOCUMENTO AUXILIAR DA NOTA FISCAL DE ENERGIA ELETRICA ELETRONICA
#
# 4
#
# AV.JOAO DE BARROS, 111, BOA VISTA, RECIFE, PERNAMBUCO CEP 50050-902
# neoenergiapernambuco.com.briLigue gratis 116 CNPJ 10.835.932/0001-08 INSCRIGAO ESTADUAL 0005943-93
#
# Tarifa Social de Energia Elétrica - Lei 10.438, de 26/04/02
#
# NOME DO CLIENTE:
#
# DROGATIM DROGARIAS LTDA CODIGO DA INSTALAGAO
#
# CNPJ: 06.198.619/0001-39
#
# ENDEREGO: 1180479
#
# AV DQ DE CAXIAS 422
#
# HELIOPOLIS/GARANHUNS. CODIGO DO CLIENTE
#
# 55299-437 GARANHUNS PE 7041645185
# REF:MES/ANO TOTAL A PAGAR RS. VENCIMENTO
# 11/2023 628,26 15/12/2023
#
# NOTA FISCAL N° 285024981 - SERIE 000 / DATA DE EMISSAO: 01/12/2023
# Consulte pela Chave de Acesso em:
#
# https://dfe-portal.svrs.rs.gov. briNf3e/consulta
#
# chave de acesso:
#
# 2623 1210 8359 3200 0108 6600 0285 0249 8110 1508 0500
#
# Protocolo de autorizagao: 3262300044435594 - 01/12/2023 as 17:02:59
#
# CLASSIFICAGAO: B3 COMERCIAL -COMERCIAL
#
# TIPO DE FORNECIMENTO: Conv. Monémia - Monofasico
#
# Cadastra-se e receba a sua fatura por e-mail, utilizando o QR code no verso da fatura.
#
# DATAS DE LEITURAS LEITURA ANTERIOR 25/10/2023 LEITURA ATUAL 25/11/2023 N°DEDIAS 31 PROXIMA LEITURA 26/12/2023
# ITENS DA FATURA UNID. QUANT. IPRECO UNIT. VALOR PIS/ BASE CALC. |ALIQUOTA| ICMS (R$) TARIFA |TRIBUTO| BASE DE juiauora] VALOR (R$)
# COM TRIB.(RS)| (R$) COFINS(R$) ICMS(R$) ICMS(%) UNIT(RS) CALCULO (RS)| _(%)
# \Consumo-TUSD kWh 557,07) 0,54941336 306,06 14,00 306,06} 18,00 55,09] 0,42538000| | P'S ee aa 48
# \Consumo-TE kWh 557,07) 0,43796270 243,97 11,16 243,97| 18,00 43,91] 0,33909000} | COFINS| aet0z) = 4b 20770
# llum. Pub. Municipal 70,07 Toms 85003) 18,00 98,00
# IICMS-CDE NF276667583 8,16
# CONSUMO / kWh
# CONSUMO FATURADO _N'DIAS FAT
# NOV23 557 31
# OUT23 a 566 30
# SET23 Cy 1742 32
# AGO23 E77 2206 30
# JUL23 2303 32
# JUN23 EE 2706 29
# MAI23, = 3302 31
# ABR23 Ln 3546 31
# MAR23 3412 29
# FEV23 a 3406 30
# JAN23 3062 29
# DEZ22 | 3045 32
# TOTAL 628,26 Nov22 2808 30
# MEDIDOR GRANDEZAS POSTOS LEITURA LEITURA. CONST. CONSUMO RESERVADO AO FISCO
# HORARIOS. ANTERIOR ATUAL MEDIDOR kWh Cobranga ICMS sobre subvengao CDE, conforme Decreto Estadual 39.459/13.
# 3212392480 | Energia Ativa Unico 71.296,00 74.692,00 1,00000 557,07
#
# é a emissdo desta fatura vocé nao
#
# ossui débitos para esse cédii
#
# es go de cliente.Parabéns por manter suas contas em dia! Cont
# mpre com a gente. Este comunicado nao contempla débitos em discussao judicial.A compensagao do pagamento ocorrera e'
# ité 3 dias uteis, apds data do pagamento.
#
# INFORMAGOES IMPORTANTES
#
# Na data da'leitura a bandeira em vigor é a Verde. Mais informagdes em www.aneel.gov.br.
#
# No valor do consumo faturado esta inclufdo o ajuste na(s) funcao(des) CAT de - 2838.93 kWh
#
# Unidade integrante de sistema de compensacao. Total de credi tos utilizados na unidade: 2838,93352 kWh
#
# 11/2023
#
# copico bo ciiente 7041645185
#
# veNcIMENTO 15/12/2023
#
# TOTAL A PAGAR R$ 628,26
#
# PARA CADASTRAR SUA CONTA EM DEBITO AUTOMATICO, UTILIZE O CODIGO DO CLIENTE.
#
# Pagamento através de Débito Automatico em Conta Corrente.
#
# anco 033-7
#
# Agéncia 3737
#
# Como gébito automatico sua conta fica sempre em dia. Vocé pode
#
# solicitar o cancelamento do servico a qual
# Para mais informagoes ligue 1
#
# Iquer momento.
# %
#
#
# (@ Neoenergia .
# COMPANHIA ENERGETICA DE PERNAMBUCO
#
# Pernambuco AV.JOAO DE BARROS, 111, BOA VISTA, RECIFE, PERNAMBUCO CEP 50050-902
# neoenergiapernambuco.com.briLigue gratis 116 CNPJ 10.835.932/0001-08 INSCRIGAO ESTADUAL 0005943-93
#
# DANFE - DOCUMENTO AUXILIAR DA NOTA FISCAL DE ENERGIA ELETRICA ELETRONICA
#
# 4
#
# Tarifa Social de Energia Elétrica - Lei 10.438, de 26/04/02
#
# NOME DO CLIENTE:
#
# DROGATIM DROGARIAS LTDA CODIGO DA INSTALAGAO
#
# CNP4J: 06.198.619/0096-08 Inscrigao Estadual: 107757907
#
# ENDEREGO: 7162007
#
# AV SOUZA FILHO 681
#
# CENTRO/PETROLINA CODIGO DO CLIENTE
#
# 56302-370 PETROLINA PE 7047539735 chave de acesso:
# REF:MES/ANO TOTAL A PAGAR RS VENCIMENTO
# 12/2023 6.228,77 12/12/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov. briNf3e/consulta
#
# 2623 1210 8359 3200 0108 6600 0285 0772 9420 0969 3937
# Protocolo de autorizagao: 3262300044642557 - 06/12/2023 as 03:52:16
#
# NOTA FISCAL N° 285077294 - SERIE 000 / DATA DE EMISSAO: 05/12/2023
#
# CLASSIFICAGAO: B3 COMERCIAL -OUTROS SERVIGOS E OUTRAS ATIVIDADES
#
# TIPO DE FORNECIMENTO: Conv. Monémia - Trifasico
#
# Cadastra-se e receba a sua fatura por e-mail, utilizando o QR code no verso da fatura.
#
# DATAS DE LEITURAS LEITURA ANTERIOR 03/11/2023 LEITURA ATUAL 05/12/2023 N°DEDIAS 32 PROXIMA LEITURA 04/01/2024
# ITENS DA FATURA UNID. QUANT. IPRECO UNIT. VALOR PIS/ BASE CALC. |ALIQUOTA| ICMS (R$) TARIFA |TRIBUTO| BASE DE juiauora] VALOR (R$)
# COM TRIB.(RS)| (R$) COFINS(R$) ICMS(R$) ICMS(%) UNIT(RS) CALCULO (RS)| _(%)
# \Consumo-TUSD kWh 5.692,00] 0,54941336 3.127,26 143,10 3.127,26| 18,00 562,91| 0,42538009] | P'S S’G0B,4 oe. as.62
# \Consumo-TE kWh 5.692,00] 0,43796270 2.492,88 114,05 2.492,88| 18,00 448,71| 0,33909000| | COFINS} SIG0B,EA 452 28:
# llum. Pub. Municipal 588,64 Toms S208) 18,00 ‘Ont.
# IICMS-CDE NF276839166 19,99
# CONSUMO / kWh
# CONSUMO FATURADO _N'DIAS FAT
# DEZ23 5692 32
# NOV23 Ea 5147 30
# OUT23 Tl 4268 30
# SET23 aE 4483 32
# AGO23 3821 3
# JUL23 Ey 3605 31
# JUN23 | 4436 29
# MAI23. | 4901 31
# ABR23 5134 32
# MAR23 | 4380 28
# FEV23 156 30
# JAN23 | 100 23
# [TOTAL 6.228,77 DEZ22
# MEDIDOR GRANDEZAS POSTOS LEITURA LEITURA. CONST. CONSUMO RESERVADO AO FISCO
# HORARIOS. ANTERIOR ATUAL MEDIDOR kWh Cobranga ICMS sobre subvengao CDE, conforme Decreto Estadual 39.459/13.
# 3212498857 | Energia Ativa Unico 40.389,00 46.081,00 1,00000 5.692,00
# 3212498857 | Energia Reativa Unico 13.474,00 15.641,00 1,00000 2.167,00
#
# é a emissdo desta fatura vocé nao possui débitos para esse cédi
# mpre com a gente. Este comunicado nao contempla débitos em
# ité 3 dias uteis, apds data do pagamento.
#
# go de cliente.Parabéns por manter suas contas em dia! Cont
# jiscussao judicial.A compensagao do pagamento ocorrera e'
#
# INFORMAGOES IMPORTANTES
# Na data da leitura a bandeira em vigor é a Verde. Mais informagdes em www.aneel.gov.br.
#
# copico bo cliente 7047539735 VENCIMENTO 12/12/2023
#
# TOTAL A PAGAR R$
#
# 6.228,77
#
# 12/2023
#
# PARA CADASTRAR SUA CONTA EM DEBITO AUTOMATICO, UTILIZE O CODIGO DO CLIENTE.
#
# Pagamento através de Débito Automatico em Conta Corrente.
#
# 3 anco 033-7 _Agéncia 3737 | mn
# Com o débito automatico sua conta fica sempre em dia. Vocé pode
# solicitar o cancelamento do servico a qualquer momento.
# Para mais informagoes ligue 11

# %%
path = r'C:/Program Files/Tesseract-OCR'
imagem = cv2.imread(r"C:/Users/jvict/Documents/seven/seven/[05230009002822]LOJA28ENERGISA.jpg")
pytesseract.pytesseract.tesseract_cmd = path + r'/tesseract.exe'
texto = pytesseract.image_to_string(imagem)

print(texto)
# Out:
# G 174743- Abril/2021
#
# @enercaisa
#
# ROTEIRO: 007 - 0006 - 504 - 4460
# MATRICULA: 42467-2023-11-8
#
# DOM. BANC.:
#
# DOM. ENT:
#
# Classificago: MTC-CONVENCIONAL BAIXA TENSAO / B3
#
# COMERCIAL / OUTROS SERVICOS E OUTRAS ATIVIDADES
#
# LIGAGAO: TRIFASICO
#
# TENSAO NOMINAL EM VOLTS _DISP: Lim. Min.: 380 Lim. Max.: 399
# COMERCIAL DRUGSTORE LTDA
# AV PRES EPITACIO PESSOA, 402 - 8040000 CODIGO DO CLIENTE
# TORRE 5/42467-1
# JOAO PESSOA (AG: 1)
# CODIGO DA INSTALAGAO
#
# CNPJ/CPF/RANI: OX.XXX.XXX/XXX8-22_
# Insc. Est.: 161XXXXXX W7034801514
#
# REF: MES / ANO VENCIMENTO TOTAL A PAGAR
#
# Novembro / 2023 26/12/2023 R$ 5.626,69
#
# Data de Apresentagao: 20/11/2023
# Cadastre sua Fatura em Débito Automatico.
#
# Utilize 0 Cédigo: 0000042467-1
# Lei Leit 2
# pc
# Datas de Leitura
# Leituras | 44/10/2023 13/11/2023 33 13/12/2023
#
# NOTA FISCAL N°: 002.128.740 - Série: 002
# DATA DE EMISSAO:14/11/2023
#
# Consulte pela Chave de Acesso em:
# https://dfe-portal.svrs.rs.gov.brinf3e/consulta
# chave de acesso:
#
# 2523 1109 0951 8300 0140 6600 2002 1287 4010 7194
# 1770
#
# Protocolo de Autorizacao:
# 32523000216087117 - 14/11/2023 13:45:00
#
# ~"Problemas com alcoolismo? Nés podemos ajudar — Ligue: (83) 3222-4557 / 9 8658-4556" - Alcodlicos Anénimos na Paraiba
#
# Prego unit (R$) Pis/ Base Calc. % Aliq. icms Tarifa) Base de Aliquota Valor
# Hens da Fatura Unid. Quant. comtributos Valor (R$) COFINS (R$) _ICMS (R$) ICMS. (RS) Unit (Rs) | Tuto Calc(R$)__(%) (RS)
# Consumo em kWh KWH 6.82600 0,770370 5.25859 201,50 5.25859. 18 946,54 0,602190 one ee ee ae
#
# LANCAMENTOS E SERVIGOS aa :
# CONTRIB SERV.ILUM.PUBLICA 368,10 0,00 000 0 0,00 IMS i
#
# Ne DIAS
#
# CONSUMO FATURADO FAT
# \ov23 28
# ur 33
# E123 29
# 02 28
# Uw 28
# Nn 33
# 23 31
# A823 as 29
# VAR 23 32
# V3 30
# N23 33
# 0222 29
# V2? 29
#
# TOTAL: 5.62669 201,50 5.258,59 946,54
# Medidor Grandezas Postos Leitura Leitura Const Consumo RESERVADO AO FISCO
# horérios Anterior tual Medidor kWh
# W7034801514 Energia ativa em kWh Ponta 222466 229292 1 6826 Art. 13, Inciso VII do RICMS/PB - 1997
#
# MATRICULA
# 42467-2023-11-8
#
# NOTA FISCAL/CONTA DE ENERGIA ELETRICA
#
# VENCIMENTO
# 26/12/2023
#
# FATURA A SER QUITADA ATRAVES DE DEBITO AUTOMATICO
# CONSIDERAR ESTA NOTA FISCAL QUITADA SOMENTE APOS O EFETIVO DEBITO
#
# NO BANCO 0356
#
# N° FATURA
# 2128740
#
# TOTAL A PAGAR
# R$ 5.626,69

# %%
def remove_jpg_files(folder_path):
    try:
        # List all files in the specified folder
        files = os.listdir(folder_path)

        # Filter and remove JPG files
        for file in files:
            if file.lower().endswith(".jpg"):
                file_path = os.path.join(folder_path, file)
                os.remove(file_path)
                print(f"Removed: {file_path}")

        print("JPG files removed successfully.")
    
    except Exception as e:
        print(f"Error: {e}")

# Replace 'your_folder_path' with the actual path of the folder containing the JPG files
folder_path = r"C:\Users\jvict\Documents\seven\seven"
remove_jpg_files(folder_path)
# Out:
# Removed: C:\Users\jvict\Documents\seven\seven\[05230009002822]LOJA28ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000139]LOJA17ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619000724]LOJA33ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619001704]LOJA31ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619002000]LOJA42ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619003740]LOJA60ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619004711]LOJA 36CELPE.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619005106]LOJA 38EQUATORIAL.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006170]LOJA74ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619006250]LOJA65ENERGISA.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619008547]LOJA151CELPE.jpg
# Removed: C:\Users\jvict\Documents\seven\seven\[06198619009608]LOJA163CELPE.jpg
# JPG files removed successfully.

# %%
data,cnpj_prestador,cnpj_tomador,valor,n_nota,cod_ver,image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data,cnpj_prestador,cnpj_tomador,valor,n_nota,cod_ver,image
#
# NameError: name 'data' is not defined
